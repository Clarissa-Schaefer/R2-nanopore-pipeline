# %% [markdown]
# # Feature Classification

# %% [markdown]
# - merging criteria control (they should use the reference location to decide whether an alignment should happen)
#     i adapted the merging criteria so that they refer to the position on the reference (instead of adjacent features)of course!

# %%
import os
from Bio import SeqIO
import matplotlib.pyplot as plt

from collections import defaultdict
from Bio.SeqFeature import SeqFeature, FeatureLocation

# %% [markdown]
# ## 1. Reference Fasta Parsing

# %%
def parse_reference_fasta(ref_fasta):
    """
    Read reference FASTA, parse known feature segments, return dict of feature lengths.
    """
    feature_lengths = {}
   
    for record in SeqIO.parse(ref_fasta, "fasta"):
        # Possibly parse annotation from record.description, or use a separate table.
        feature_lengths[record.id] = len(record.seq)    


    # Compute combined length
    if "Transgene" in feature_lengths and "3UTR" in feature_lengths:
        feature_lengths["Insert"] = (
            feature_lengths["Transgene"] + feature_lengths["3UTR"]
        )
    else:
        print("Warning: Missing feature lengths for Transgene and/or 3UTR.")

    return feature_lengths

ref_fasta_path = "00-Data/references/ref_28s_features.fasta"
ref_lengths = parse_reference_fasta(ref_fasta_path)
ref_lengths
ref_Transgene_len = ref_lengths["Transgene"]

# %% [markdown]
# ## 2. RepeatMasker Reference Location Parser
#
# Get the location for each read-feature pair in relation to the referece/database

# %%
# Store as (read_id, type) -> [(start, end, strand), ...]
read_ref_positions = defaultdict(list)
for line in open("00-Data/repeatmaskered/sample-cutadapt_sup-filtered.fasta.out.xm"):
    # Split the line on whitespace
    line=line.strip().split()
    # Extract the relevant information
    read_id = f"{line[4]}"
    strand = line[8]
    type = line[9].split("#")[0]

    # Pick start/end depending on strandedness
    if strand == "+":
        start = int(line[10])
        end = int(line[11])
    elif strand == "C":
        start = int(line[12])
        end = int(line[11])
    
    read_ref_positions[(read_id, type)].append((start, end, strand))

read_ref_positions[("e6a618ab-0e63-4525-b142-63ee327895e0", "Transgene")]
# Out:
# [(1123, 1402, 'C'), (1, 1362, 'C')]

# %% [markdown]
# ## 3. Parse Genbank File

# %%
##################################################
# 2. PARSE GENBANK READS
##################################################

def get_feature_info(read_record, allowed_gap=10):
    """
    Extract relevant feature information from each read’s GenBank annotation.
    Return:
      - dictionary of feature lengths (keyed by feature name)
      - largest contiguous insertion region (Transgene+UTR, ignoring 3end/5end in between)
      - list of inter-feature gaps
    """
    # track the length of each feature
    feature_dict = defaultdict(list)
    # track the sorted positions of features to find inter-feature gaps
    feature_positions = []
    
    for feat in read_record.features:
        # E.g., "3end_200nt", "5end_200nt", "3UTR", "Transgene", etc.
        start = int(feat.location.start)
        end   = int(feat.location.end)
        length = end - start
        feature_dict[feat.type] += [{
            "start": start,
            "end": end,
            "length": length, 
            "strand": feat.strand
        }]
        feature_positions.append((start, end, feat.type))

    # Sort features by their start coordinate to find largest contiguous insertion
    feature_positions.sort(key=lambda x: x[0])

    # Identify consecutive "Transgene + 3UTR" region

    # We’ll store all consecutive segments that have type in ["Transgene", "UTR"] 
    valid_types = {"Transgene","3UTR"}  # Adjust if your naming differs
    longest_contig_length = 0

    current_start, current_end = None, None
    
    for start, end, ftype in feature_positions:
        # Ignore features that are not part of the insertion region
        if ftype not in valid_types:
            continue
        
        # Initialize the current segment with the first feature
        if current_start is None:
            current_start = start
            current_end = end
            continue

        # Check if the current segment is entirely part of the previous segment
        if start >= current_start and end <= current_end:
            continue

        # Check if the segment can be merged with the current segment
        if start <= current_end + allowed_gap:
            current_end = max(current_end, end)
        else:
            # Update the longest segment length
            longest_contig_length = max(longest_contig_length, current_end - current_start)
            # Start a new current segment
            current_start, current_end = start, end

    # Final check for the last segment
    if current_start is None:
        max_insertion_len = 0
    else:
        max_insertion_len = max(longest_contig_length, current_end - current_start)


    #  compute inter-feature gaps
    # (distance between end of feature i and start of feature i+1)
    inter_gaps = []
    for i in range(len(feature_positions) - 1):
        _, end_i, _ = feature_positions[i]
        start_j, _, _ = feature_positions[i+1]
        gap_len = start_j - end_i
        inter_gaps.append(gap_len)

    longest_inter_gap = max(inter_gaps) if inter_gaps else 0

    return feature_dict, max_insertion_len, longest_inter_gap

# Test run the function
gb_file = "00-Data/feature_annotated/Repeatmasker_transgene_filtered.gb"
for read_record in SeqIO.parse(gb_file, "genbank"):
    feature_dict, max_insertion_len, max_inter_gap = get_feature_info(read_record)
    print(f"Read {read_record.id}:")    
    print(f"  Feature lengths: {feature_dict}")
    print(f"  Insertion length: {max_insertion_len}")
    print(f"  Longest inter-feature gap: {max_inter_gap}")
    # break
# Out:
# Read 0702e822-673e-4cf2-a935-b9c8fe1fff04:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 205, 'length': 205, 'strand': 1}], '5end_200nt': [{'start': 205, 'end': 405, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 405, 'end': 1811, 'length': 1406, 'strand': 1}], '3UTR': [{'start': 1811, 'end': 1912, 'length': 101, 'strand': 1}], '3end_200nt': [{'start': 1912, 'end': 2112, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2112, 'end': 2311, 'length': 199, 'strand': 1}]})
#   Insertion length: 1507
#   Longest inter-feature gap: 0
# Read cbfe3b25-179c-40c2-9f86-08dd1038c4ae:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2103, 'end': 2304, 'length': 201, 'strand': 1}], '3end_200nt': [{'start': 1903, 'end': 2103, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1803, 'end': 1903, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 401, 'end': 1803, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 201, 'end': 401, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 201, 'length': 201, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read ee575744-c8dd-4d21-97b1-37cdb7e9d3a5:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 200, 'length': 200, 'strand': 1}], '5end_200nt': [{'start': 202, 'end': 398, 'length': 196, 'strand': 1}], 'Transgene': [{'start': 398, 'end': 1803, 'length': 1405, 'strand': 1}], '3UTR': [{'start': 1803, 'end': 1903, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1903, 'end': 2103, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2103, 'end': 2302, 'length': 199, 'strand': 1}]})
#   Insertion length: 1505
#   Longest inter-feature gap: 2
# Read 2cbc6e8e-532a-4805-88ea-e99c6225a30e:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 205, 'length': 205, 'strand': 1}], '5end_200nt': [{'start': 205, 'end': 405, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 405, 'end': 1806, 'length': 1401, 'strand': 1}], '3UTR': [{'start': 1806, 'end': 1906, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1906, 'end': 2104, 'length': 198, 'strand': 1}], '3end_400nt': [{'start': 2104, 'end': 2307, 'length': 203, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 0
# Read 0906aac4-1140-47ad-9391-ea4d0a353b93:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1102, 'end': 1304, 'length': 202, 'strand': 1}], '3end_200nt': [{'start': 905, 'end': 1099, 'length': 194, 'strand': 1}], '3UTR': [{'start': 805, 'end': 905, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 461, 'end': 805, 'length': 344, 'strand': 1}, {'start': 396, 'end': 461, 'length': 65, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 396, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 509
#   Longest inter-feature gap: 3
# Read 9f9da15f-2cc7-4213-a054-68341253349b:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2101, 'end': 2300, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1901, 'end': 2101, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1801, 'end': 1901, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 398, 'end': 1801, 'length': 1403, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 398, 'length': 202, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read 23efee78-f738-42f7-81c9-25a9a2652b61:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2085, 'end': 2269, 'length': 184, 'strand': 1}], '3end_200nt': [{'start': 1884, 'end': 2085, 'length': 201, 'strand': 1}], '3UTR': [{'start': 1784, 'end': 1884, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1784, 'length': 1388, 'strand': 1}], '5end_200nt': [{'start': 194, 'end': 397, 'length': 203, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 194, 'length': 194, 'strand': 1}]})
#   Insertion length: 1488
#   Longest inter-feature gap: 0
# Read 0a3c2e81-0706-4563-b2ad-8dc29b4237ee:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 192, 'length': 192, 'strand': 1}], '5end_200nt': [{'start': 192, 'end': 392, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 392, 'end': 463, 'length': 71, 'strand': 1}, {'start': 458, 'end': 639, 'length': 181, 'strand': 1}], '3UTR': [{'start': 639, 'end': 739, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 739, 'end': 939, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 939, 'end': 1139, 'length': 200, 'strand': 1}]})
#   Insertion length: 347
#   Longest inter-feature gap: 0
# Read 10d122b6-cd2a-4e79-88e7-7c6ce9745183:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 193, 'length': 193, 'strand': 1}], '5end_200nt': [{'start': 193, 'end': 388, 'length': 195, 'strand': 1}], 'Transgene': [{'start': 391, 'end': 977, 'length': 586, 'strand': 1}], '3UTR': [{'start': 977, 'end': 1079, 'length': 102, 'strand': 1}], '3end_200nt': [{'start': 1079, 'end': 1185, 'length': 106, 'strand': 1}]})
#   Insertion length: 688
#   Longest inter-feature gap: 3
# Read 56796ca8-8d79-4198-9203-26e12056d8a7:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2100, 'end': 2298, 'length': 198, 'strand': 1}], '3end_200nt': [{'start': 1899, 'end': 2099, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1899, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 405, 'end': 1799, 'length': 1394, 'strand': 1}], '5end_200nt': [{'start': 205, 'end': 405, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 205, 'length': 205, 'strand': 1}]})
#   Insertion length: 1494
#   Longest inter-feature gap: 1
# Read 5cf9af87-da19-4d70-8f70-c06a53b45940:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 205, 'length': 205, 'strand': 1}], '5end_200nt': [{'start': 205, 'end': 403, 'length': 198, 'strand': 1}], 'Transgene': [{'start': 403, 'end': 1802, 'length': 1399, 'strand': 1}], '3UTR': [{'start': 1802, 'end': 1902, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1902, 'end': 2102, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2102, 'end': 2302, 'length': 200, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 0
# Read 4c609a4e-0611-4f8a-8c80-64dcb2e3442a:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 204, 'length': 204, 'strand': 1}], '5end_200nt': [{'start': 204, 'end': 407, 'length': 203, 'strand': 1}], 'Transgene': [{'start': 407, 'end': 1808, 'length': 1401, 'strand': 1}], '3UTR': [{'start': 1808, 'end': 1908, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1908, 'end': 2108, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2108, 'end': 2310, 'length': 202, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 0
# Read 00246098-a235-4592-a6be-52eb1e51b86a:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 205, 'length': 205, 'strand': 1}], '5end_200nt': [{'start': 205, 'end': 405, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 405, 'end': 1807, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1807, 'end': 1907, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1907, 'end': 2107, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2107, 'end': 2306, 'length': 199, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 15ab611b-96e0-4538-804a-63c57bb657ac:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 397, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1798, 'length': 1401, 'strand': 1}], '3UTR': [{'start': 1798, 'end': 1898, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1898, 'end': 2098, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2098, 'end': 2299, 'length': 201, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 0
# Read cb9faa57-2219-406d-86fc-824fcda9f271:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 189, 'length': 189, 'strand': 1}], '5end_200nt': [{'start': 189, 'end': 388, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 392, 'end': 1666, 'length': 1274, 'strand': 1}], '3UTR': [{'start': 1666, 'end': 1766, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1766, 'end': 1966, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1972, 'end': 2164, 'length': 192, 'strand': 1}]})
#   Insertion length: 1374
#   Longest inter-feature gap: 6
# Read dc1034e7-41a1-48fe-8d33-5bd17d89bd6d:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2106, 'end': 2306, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1906, 'end': 2106, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1805, 'end': 1906, 'length': 101, 'strand': 1}], 'Transgene': [{'start': 404, 'end': 1805, 'length': 1401, 'strand': 1}], '5end_200nt': [{'start': 204, 'end': 404, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 204, 'length': 204, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 7f51b131-ab42-4538-9294-76cac552aa12:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 189, 'length': 189, 'strand': 1}], '5end_200nt': [{'start': 189, 'end': 390, 'length': 201, 'strand': 1}], 'Transgene': [{'start': 390, 'end': 1794, 'length': 1404, 'strand': 1}], '3UTR': [{'start': 1794, 'end': 1894, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1894, 'end': 2094, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2093, 'end': 2296, 'length': 203, 'strand': 1}]})
#   Insertion length: 1504
#   Longest inter-feature gap: 0
# Read 55f24861-1606-4e85-8641-9db4c79720be:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 205, 'length': 205, 'strand': 1}], '5end_200nt': [{'start': 205, 'end': 405, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 405, 'end': 1738, 'length': 1333, 'strand': 1}], '3UTR': [{'start': 1738, 'end': 1831, 'length': 93, 'strand': 1}], '3end_200nt': [{'start': 1831, 'end': 2032, 'length': 201, 'strand': 1}], '3end_400nt': [{'start': 2032, 'end': 2234, 'length': 202, 'strand': 1}]})
#   Insertion length: 1426
#   Longest inter-feature gap: 0
# Read aa721a47-f046-4c55-9051-4c69746d6af9:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2097, 'end': 2293, 'length': 196, 'strand': 1}], '3end_200nt': [{'start': 1897, 'end': 2097, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1897, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1797, 'length': 1401, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 396, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 0
# Read 9bca1bd9-a46f-44bf-8892-01cd1e2cf1f5:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2114, 'end': 2314, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1912, 'end': 2114, 'length': 202, 'strand': 1}], '3UTR': [{'start': 1812, 'end': 1912, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 409, 'end': 1812, 'length': 1403, 'strand': 1}], '5end_200nt': [{'start': 209, 'end': 409, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 209, 'length': 209, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read 960795b9-dbaa-49a8-bd98-fd90444a4f1e:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1205, 'end': 1405, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1005, 'end': 1205, 'length': 200, 'strand': 1}], '3UTR': [{'start': 905, 'end': 1005, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 383, 'end': 905, 'length': 522, 'strand': 1}], '5end_200nt': [{'start': 199, 'end': 379, 'length': 180, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 199, 'length': 199, 'strand': 1}]})
#   Insertion length: 622
#   Longest inter-feature gap: 4
# Read 0c7e04a3-452e-4294-8c30-60e9f9ac9664:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 195, 'length': 195, 'strand': 1}], '5end_200nt': [{'start': 195, 'end': 394, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 394, 'end': 1796, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1796, 'end': 1896, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1896, 'end': 2096, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2095, 'end': 2297, 'length': 202, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read aac56d1f-a1e0-43b0-927e-522e727e4b42:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2098, 'end': 2300, 'length': 202, 'strand': 1}], '3end_200nt': [{'start': 1898, 'end': 2098, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1817, 'end': 1898, 'length': 81, 'strand': 1}], 'Transgene': [{'start': 390, 'end': 1793, 'length': 1403, 'strand': 1}], '5end_200nt': [{'start': 190, 'end': 390, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 190, 'length': 190, 'strand': 1}]})
#   Insertion length: 1403
#   Longest inter-feature gap: 24
# Read 3d63a987-7191-4cbd-9e30-63d20f5a5539:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 956, 'end': 1156, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 756, 'end': 956, 'length': 200, 'strand': 1}], '3UTR': [{'start': 656, 'end': 756, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 505, 'end': 656, 'length': 151, 'strand': 1}, {'start': 409, 'end': 505, 'length': 96, 'strand': 1}], '5end_200nt': [{'start': 207, 'end': 409, 'length': 202, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 207, 'length': 207, 'strand': 1}]})
#   Insertion length: 347
#   Longest inter-feature gap: 0
# Read 9a717e76-5be5-46af-b904-84e2e3245e53:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1163, 'end': 1363, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 963, 'end': 1163, 'length': 200, 'strand': 1}], '3UTR': [{'start': 863, 'end': 963, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 400, 'end': 863, 'length': 463, 'strand': 1}], '5end_200nt': [{'start': 202, 'end': 402, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 202, 'length': 202, 'strand': 1}]})
#   Insertion length: 563
#   Longest inter-feature gap: 0
# Read 3e959cbb-9bba-4f9d-b8c9-be19380ad03c:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 203, 'length': 203, 'strand': 1}], '5end_200nt': [{'start': 203, 'end': 382, 'length': 179, 'strand': 1}], 'Transgene': [{'start': 381, 'end': 784, 'length': 403, 'strand': 1}], '3UTR': [{'start': 784, 'end': 884, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 884, 'end': 1084, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1084, 'end': 1284, 'length': 200, 'strand': 1}]})
#   Insertion length: 503
#   Longest inter-feature gap: 0
# Read d080e280-4643-413d-8e87-4c851ceee3b3:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 195, 'length': 195, 'strand': 1}], '5end_200nt': [{'start': 195, 'end': 395, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 395, 'end': 1797, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1897, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1900, 'end': 2097, 'length': 197, 'strand': 1}], '3end_400nt': [{'start': 2100, 'end': 2295, 'length': 195, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 3
# Read f9fde51f-e425-412b-9e41-f4f3933cef21:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1447, 'end': 1648, 'length': 201, 'strand': 1}], '3end_200nt': [{'start': 1248, 'end': 1447, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1148, 'end': 1248, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 1078, 'end': 1148, 'length': 70, 'strand': 1}, {'start': 397, 'end': 1079, 'length': 682, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 397, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 851
#   Longest inter-feature gap: 0
# Read f64650fc-7326-4950-869a-1f77b7cfc30c:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2108, 'end': 2300, 'length': 192, 'strand': 1}], '3end_200nt': [{'start': 1908, 'end': 2108, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1808, 'end': 1908, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 408, 'end': 1808, 'length': 1400, 'strand': 1}], '5end_200nt': [{'start': 208, 'end': 408, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 208, 'length': 208, 'strand': 1}]})
#   Insertion length: 1500
#   Longest inter-feature gap: 0
# Read feca90d7-6b97-43f8-9c72-72d1f0fe0384:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 204, 'length': 204, 'strand': 1}], '5end_200nt': [{'start': 204, 'end': 404, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 797, 'length': 400, 'strand': 1}], '3UTR': [{'start': 797, 'end': 894, 'length': 97, 'strand': 1}], '3end_200nt': [{'start': 894, 'end': 1094, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1094, 'end': 1294, 'length': 200, 'strand': 1}]})
#   Insertion length: 497
#   Longest inter-feature gap: 0
# Read 0cb6e235-ee9c-45c7-8e54-879f822b2ee6:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1716, 'end': 1913, 'length': 197, 'strand': 1}], '3end_200nt': [{'start': 1516, 'end': 1716, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1419, 'end': 1516, 'length': 97, 'strand': 1}], 'Transgene': [{'start': 1337, 'end': 1419, 'length': 82, 'strand': 1}, {'start': 399, 'end': 1345, 'length': 946, 'strand': 1}], '5end_200nt': [{'start': 198, 'end': 399, 'length': 201, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 198, 'length': 198, 'strand': 1}]})
#   Insertion length: 1117
#   Longest inter-feature gap: 0
# Read 5346ed4c-6f4e-48a9-95af-6ba325845de5:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1231, 'end': 1429, 'length': 198, 'strand': 1}], '3end_200nt': [{'start': 1031, 'end': 1231, 'length': 200, 'strand': 1}], '3UTR': [{'start': 931, 'end': 1031, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 384, 'end': 931, 'length': 547, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 387, 'length': 190, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 647
#   Longest inter-feature gap: 0
# Read 350526fe-7456-48ef-91be-00f9e4cca1a7:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2099, 'end': 2299, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1899, 'end': 2099, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1899, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1799, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 397, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 68b331b2-be3d-4c8d-b194-96e8c5cd136b:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 192, 'length': 192, 'strand': 1}], '5end_200nt': [{'start': 192, 'end': 382, 'length': 190, 'strand': 1}], 'Transgene': [{'start': 379, 'end': 926, 'length': 547, 'strand': 1}], '3UTR': [{'start': 926, 'end': 1026, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1026, 'end': 1226, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1232, 'end': 1423, 'length': 191, 'strand': 1}]})
#   Insertion length: 647
#   Longest inter-feature gap: 6
# Read bb4c5bd5-65da-4579-8266-1ab3310f4f7e:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1891, 'end': 2091, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1692, 'end': 1891, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1591, 'end': 1692, 'length': 101, 'strand': 1}], 'Transgene': [{'start': 385, 'end': 1591, 'length': 1206, 'strand': 1}], '5end_200nt': [{'start': 203, 'end': 385, 'length': 182, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 203, 'length': 203, 'strand': 1}]})
#   Insertion length: 1307
#   Longest inter-feature gap: 0
# Read be66b2c5-0fc5-40ae-9b87-0e3c154b91c9:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 202, 'length': 202, 'strand': 1}], '5end_200nt': [{'start': 202, 'end': 384, 'length': 182, 'strand': 1}], 'Transgene': [{'start': 384, 'end': 1591, 'length': 1207, 'strand': 1}], '3UTR': [{'start': 1591, 'end': 1691, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1691, 'end': 1889, 'length': 198, 'strand': 1}], '3end_400nt': [{'start': 1889, 'end': 2089, 'length': 200, 'strand': 1}]})
#   Insertion length: 1307
#   Longest inter-feature gap: 0
# Read 3dceec76-d51a-4b86-bbb1-70c9e9ade9b1:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2088, 'end': 2286, 'length': 198, 'strand': 1}], '3end_200nt': [{'start': 1889, 'end': 2088, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1789, 'end': 1889, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 390, 'end': 1789, 'length': 1399, 'strand': 1}], '5end_200nt': [{'start': 194, 'end': 386, 'length': 192, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 194, 'length': 194, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 4
# Read 9e57b10e-a93d-4a26-8bd9-d0546c0a35f8:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1116, 'end': 1313, 'length': 197, 'strand': 1}], '3end_200nt': [{'start': 918, 'end': 1116, 'length': 198, 'strand': 1}], '3UTR': [{'start': 818, 'end': 918, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 400, 'end': 818, 'length': 418, 'strand': 1}], '5end_200nt': [{'start': 206, 'end': 403, 'length': 197, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 206, 'length': 206, 'strand': 1}]})
#   Insertion length: 518
#   Longest inter-feature gap: 0
# Read dd26b47a-cd76-42f4-94b5-df9c90228965:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 207, 'length': 207, 'strand': 1}], '5end_200nt': [{'start': 207, 'end': 406, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 407, 'end': 1269, 'length': 862, 'strand': 1}], '3UTR': [{'start': 1269, 'end': 1369, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1369, 'end': 1569, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1569, 'end': 1769, 'length': 200, 'strand': 1}]})
#   Insertion length: 962
#   Longest inter-feature gap: 1
# Read 5fc3296a-0161-448c-90bb-a3b025c9a699:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2110, 'end': 2310, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1911, 'end': 2110, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1811, 'end': 1911, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 409, 'end': 1811, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 208, 'end': 409, 'length': 201, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 208, 'length': 208, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 774e1256-14da-4a9a-bd40-239615d6a0f6:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 187, 'length': 187, 'strand': 1}], '5end_200nt': [{'start': 187, 'end': 386, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 386, 'end': 1784, 'length': 1398, 'strand': 1}], '3UTR': [{'start': 1788, 'end': 1888, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1888, 'end': 2088, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2088, 'end': 2285, 'length': 197, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 4
# Read e0542464-0980-44e3-891a-82cf5d11b01c:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 203, 'length': 203, 'strand': 1}], '5end_200nt': [{'start': 203, 'end': 380, 'length': 177, 'strand': 1}], 'Transgene': [{'start': 403, 'end': 1805, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1805, 'end': 1905, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1905, 'end': 2105, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2105, 'end': 2304, 'length': 199, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 23
# Read 8893e424-2054-4cc4-9bd5-bc2872711f33:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 199, 'length': 199, 'strand': 1}], '5end_200nt': [{'start': 199, 'end': 399, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 399, 'end': 1800, 'length': 1401, 'strand': 1}], '3UTR': [{'start': 1800, 'end': 1900, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1900, 'end': 2101, 'length': 201, 'strand': 1}], '3end_400nt': [{'start': 2101, 'end': 2300, 'length': 199, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 0
# Read fdaba0c2-0831-48a6-966d-c58ee5635dd5:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 209, 'length': 209, 'strand': 1}], '5end_200nt': [{'start': 209, 'end': 409, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 409, 'end': 1812, 'length': 1403, 'strand': 1}], '3UTR': [{'start': 1812, 'end': 1912, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1912, 'end': 2113, 'length': 201, 'strand': 1}], '3end_400nt': [{'start': 2111, 'end': 2306, 'length': 195, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read b5fe0c3e-48a0-4846-9b14-e785738a43ce:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2106, 'end': 2306, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1907, 'end': 2106, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1807, 'end': 1907, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 404, 'end': 1807, 'length': 1403, 'strand': 1}], '5end_200nt': [{'start': 204, 'end': 404, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 204, 'length': 204, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read f8ebdd2a-f02c-42a2-896b-405fdb8f7d23:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2097, 'end': 2287, 'length': 190, 'strand': 1}], '3end_200nt': [{'start': 1894, 'end': 2094, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1794, 'end': 1894, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 393, 'end': 1794, 'length': 1401, 'strand': 1}], '5end_200nt': [{'start': 194, 'end': 393, 'length': 199, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 194, 'length': 194, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 3
# Read 10e1da43-7100-495f-b43d-b5617f4e1436:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 190, 'length': 190, 'strand': 1}], '5end_200nt': [{'start': 190, 'end': 389, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 366, 'end': 1689, 'length': 1323, 'strand': 1}], '3UTR': [{'start': 1689, 'end': 1789, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1789, 'end': 1989, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1989, 'end': 2188, 'length': 199, 'strand': 1}]})
#   Insertion length: 1423
#   Longest inter-feature gap: 0
# Read f745248b-0c1c-4b73-8c75-dca40b14df25:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 194, 'length': 194, 'strand': 1}], '5end_200nt': [{'start': 194, 'end': 394, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 394, 'end': 1797, 'length': 1403, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1897, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1897, 'end': 2097, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2097, 'end': 2297, 'length': 200, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read f576dd37-1d18-4c67-ab28-8d7db3e479e5:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1709, 'end': 1908, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1509, 'end': 1709, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1408, 'end': 1509, 'length': 101, 'strand': 1}], 'Transgene': [{'start': 393, 'end': 1408, 'length': 1015, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 393, 'length': 197, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 1116
#   Longest inter-feature gap: 0
# Read 2ca726ea-5e66-4b40-af3c-27f98da750db:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2125, 'end': 2328, 'length': 203, 'strand': 1}], '3end_200nt': [{'start': 1925, 'end': 2125, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1825, 'end': 1925, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 505, 'end': 1825, 'length': 1320, 'strand': 1}, {'start': 377, 'end': 517, 'length': 140, 'strand': 1}], '5end_200nt': [{'start': 183, 'end': 377, 'length': 194, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 183, 'length': 183, 'strand': 1}]})
#   Insertion length: 1548
#   Longest inter-feature gap: 0
# Read 4e50ff48-4b28-4a16-9431-d1f896bc4d2c:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 195, 'length': 195, 'strand': 1}], '5end_200nt': [{'start': 195, 'end': 396, 'length': 201, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1803, 'length': 1407, 'strand': 1}], '3UTR': [{'start': 1803, 'end': 1903, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1903, 'end': 2100, 'length': 197, 'strand': 1}], '3end_400nt': [{'start': 2100, 'end': 2300, 'length': 200, 'strand': 1}]})
#   Insertion length: 1507
#   Longest inter-feature gap: 0
# Read ffae9bca-2b17-4a1b-8bdc-09ff818b14be:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 394, 'length': 197, 'strand': 1}], 'Transgene': [{'start': 399, 'end': 1593, 'length': 1194, 'strand': 1}], '3UTR': [{'start': 1593, 'end': 1693, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1693, 'end': 1893, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1893, 'end': 2076, 'length': 183, 'strand': 1}]})
#   Insertion length: 1294
#   Longest inter-feature gap: 5
# Read 4e3b16e0-d048-4435-a854-619ff0b8b329:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2113, 'end': 2315, 'length': 202, 'strand': 1}], '3end_200nt': [{'start': 1911, 'end': 2113, 'length': 202, 'strand': 1}], '3UTR': [{'start': 1813, 'end': 1908, 'length': 95, 'strand': 1}], 'Transgene': [{'start': 409, 'end': 1813, 'length': 1404, 'strand': 1}], '5end_200nt': [{'start': 209, 'end': 409, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 209, 'length': 209, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 3
# Read aa2689df-cc5e-44b6-beef-195559158669:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 188, 'length': 188, 'strand': 1}], '5end_200nt': [{'start': 188, 'end': 387, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 387, 'end': 1469, 'length': 1082, 'strand': 1}], '3UTR': [{'start': 1469, 'end': 1569, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1569, 'end': 1770, 'length': 201, 'strand': 1}], '3end_400nt': [{'start': 1769, 'end': 1967, 'length': 198, 'strand': 1}]})
#   Insertion length: 1182
#   Longest inter-feature gap: 0
# Read 2af04115-619d-4829-8b84-5399c9184069:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2110, 'end': 2310, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1910, 'end': 2110, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1810, 'end': 1910, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 406, 'end': 1810, 'length': 1404, 'strand': 1}], '5end_200nt': [{'start': 206, 'end': 406, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 206, 'length': 206, 'strand': 1}]})
#   Insertion length: 1504
#   Longest inter-feature gap: 0
# Read 608b997f-7ae7-4064-88a9-c2bb000d2148:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 204, 'length': 204, 'strand': 1}], '5end_200nt': [{'start': 204, 'end': 404, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 404, 'end': 1806, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1806, 'end': 1906, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1906, 'end': 2106, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2105, 'end': 2305, 'length': 200, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read f5188460-1c42-447b-962e-9611c42020ed:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 207, 'length': 207, 'strand': 1}], '5end_200nt': [{'start': 207, 'end': 406, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 406, 'end': 1807, 'length': 1401, 'strand': 1}], '3UTR': [{'start': 1807, 'end': 1908, 'length': 101, 'strand': 1}], '3end_200nt': [{'start': 1908, 'end': 2108, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2108, 'end': 2309, 'length': 201, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 2bd88689-9f27-4905-ae4b-2ba7651b617c:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 191, 'length': 191, 'strand': 1}], '5end_200nt': [{'start': 191, 'end': 389, 'length': 198, 'strand': 1}], 'Transgene': [{'start': 386, 'end': 1094, 'length': 708, 'strand': 1}], '3UTR': [{'start': 1094, 'end': 1194, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1194, 'end': 1394, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1397, 'end': 1591, 'length': 194, 'strand': 1}]})
#   Insertion length: 808
#   Longest inter-feature gap: 3
# Read edaca1eb-2dd8-42bc-b744-c1781a93226b:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1389, 'end': 1589, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1200, 'end': 1388, 'length': 188, 'strand': 1}], '3UTR': [{'start': 1100, 'end': 1200, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 392, 'end': 1100, 'length': 708, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 395, 'length': 198, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 808
#   Longest inter-feature gap: 1
# Read ed6e64d2-88a6-49a5-8878-a6818add7f40:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 195, 'length': 195, 'strand': 1}], '5end_200nt': [{'start': 195, 'end': 395, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 395, 'end': 1797, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1897, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1897, 'end': 2097, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2097, 'end': 2297, 'length': 200, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 77d543e7-b213-4e0c-b532-8bc62f86498f:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1011, 'end': 1211, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 812, 'end': 1012, 'length': 200, 'strand': 1}], '3UTR': [{'start': 713, 'end': 812, 'length': 99, 'strand': 1}], 'Transgene': [{'start': 385, 'end': 713, 'length': 328, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 387, 'length': 190, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 427
#   Longest inter-feature gap: 0
# Read e2d23a23-d1d7-43d6-b4c0-195746786dfd:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 392, 'length': 195, 'strand': 1}], 'Transgene': [{'start': 393, 'end': 1095, 'length': 702, 'strand': 1}], '3UTR': [{'start': 1095, 'end': 1195, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1195, 'end': 1395, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 1395, 'end': 1595, 'length': 200, 'strand': 1}]})
#   Insertion length: 802
#   Longest inter-feature gap: 1
# Read ad028a71-ae5a-499f-b41c-10327479d9bc:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 195, 'length': 195, 'strand': 1}], '5end_200nt': [{'start': 195, 'end': 395, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 395, 'end': 1797, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1897, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1897, 'end': 2097, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2099, 'end': 2294, 'length': 195, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 2
# Read 0b3c7f09-e5ca-4616-8cb7-83301bf3f0ea:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1858, 'end': 2059, 'length': 201, 'strand': 1}], '3end_200nt': [{'start': 1661, 'end': 1858, 'length': 197, 'strand': 1}], '3UTR': [{'start': 1561, 'end': 1661, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 163, 'end': 1561, 'length': 1398, 'strand': 1}], '5end_200nt': [{'start': 0, 'end': 158, 'length': 158, 'strand': 1}]})
#   Insertion length: 1498
#   Longest inter-feature gap: 5
# Read 9eb48276-ad82-4430-a800-894730036cd9:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2109, 'end': 2309, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1909, 'end': 2109, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1809, 'end': 1909, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 407, 'end': 1809, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 207, 'end': 407, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 207, 'length': 207, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 65c899e3-f149-46ea-a4a0-e5e934bef565:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2112, 'end': 2311, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1910, 'end': 2112, 'length': 202, 'strand': 1}], '3UTR': [{'start': 1810, 'end': 1910, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 408, 'end': 1810, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 208, 'end': 408, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 208, 'length': 208, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 157502c8-0776-4fef-8d3f-1673eb6f5010:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2039, 'end': 2210, 'length': 171, 'strand': 1}], '3end_200nt': [{'start': 1841, 'end': 2039, 'length': 198, 'strand': 1}], '3UTR': [{'start': 1741, 'end': 1841, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 398, 'end': 1741, 'length': 1343, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 399, 'length': 202, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1443
#   Longest inter-feature gap: 0
# Read 003cc2c6-63c5-4526-858b-dcfdcd9d558c:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2092, 'end': 2297, 'length': 205, 'strand': 1}], '3end_200nt': [{'start': 1895, 'end': 2092, 'length': 197, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1895, 'length': 96, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1789, 'length': 1393, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 396, 'length': 199, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 10
# Read d17a436e-7bc6-4727-b679-818bd0ea7e31:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2105, 'end': 2302, 'length': 197, 'strand': 1}], '3end_200nt': [{'start': 1905, 'end': 2105, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1805, 'end': 1905, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 403, 'end': 1805, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 206, 'end': 403, 'length': 197, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 206, 'length': 206, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read ce9fc674-1c60-4c00-be8c-d5f123768d3e:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 194, 'length': 194, 'strand': 1}], '5end_200nt': [{'start': 194, 'end': 390, 'length': 196, 'strand': 1}], 'Transgene': [{'start': 386, 'end': 432, 'length': 46, 'strand': 1}], '3UTR': [{'start': 432, 'end': 532, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 532, 'end': 732, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 731, 'end': 929, 'length': 198, 'strand': 1}]})
#   Insertion length: 146
#   Longest inter-feature gap: 0
# Read c3505dc7-f6f4-4a0e-89f0-4dbede3a65ac:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 735, 'end': 932, 'length': 197, 'strand': 1}], '3end_200nt': [{'start': 536, 'end': 735, 'length': 199, 'strand': 1}], '3UTR': [{'start': 436, 'end': 536, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 390, 'end': 436, 'length': 46, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 394, 'length': 197, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 146
#   Longest inter-feature gap: 0
# Read dc37addc-a057-4120-9efa-37f235f0af85:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 395, 'length': 198, 'strand': 1}], 'Transgene': [{'start': 395, 'end': 1792, 'length': 1397, 'strand': 1}], '3UTR': [{'start': 1792, 'end': 1892, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1892, 'end': 2091, 'length': 199, 'strand': 1}], '3end_400nt': [{'start': 2091, 'end': 2292, 'length': 201, 'strand': 1}]})
#   Insertion length: 1497
#   Longest inter-feature gap: 0
# Read 0729c55c-633f-487e-815f-cb530b3daf54:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 191, 'length': 191, 'strand': 1}], '5end_200nt': [{'start': 191, 'end': 391, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 391, 'end': 1786, 'length': 1395, 'strand': 1}], '3UTR': [{'start': 1786, 'end': 1886, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1886, 'end': 1992, 'length': 106, 'strand': 1}]})
#   Insertion length: 1495
#   Longest inter-feature gap: 0
# Read 922afa24-5c6c-4467-bbcc-416dc0117c40:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2087, 'end': 2286, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1885, 'end': 2084, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1785, 'end': 1885, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 394, 'end': 1785, 'length': 1391, 'strand': 1}], '5end_200nt': [{'start': 195, 'end': 394, 'length': 199, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 195, 'length': 195, 'strand': 1}]})
#   Insertion length: 1491
#   Longest inter-feature gap: 3
# Read 1bd28ca0-74fe-4561-b18a-e2dd2016ccfe:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 194, 'length': 194, 'strand': 1}], '5end_200nt': [{'start': 194, 'end': 385, 'length': 191, 'strand': 1}], '3UTR': [{'start': 415, 'end': 515, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 515, 'end': 715, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 715, 'end': 915, 'length': 200, 'strand': 1}]})
#   Insertion length: 100
#   Longest inter-feature gap: 30
# Read a99cf926-1767-4d74-92ad-183cb9058928:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 191, 'length': 191, 'strand': 1}], '5end_200nt': [{'start': 191, 'end': 388, 'length': 197, 'strand': 1}], 'Transgene': [{'start': 387, 'end': 621, 'length': 234, 'strand': 1}], '3UTR': [{'start': 625, 'end': 714, 'length': 89, 'strand': 1}], '3end_200nt': [{'start': 714, 'end': 914, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 914, 'end': 1110, 'length': 196, 'strand': 1}]})
#   Insertion length: 327
#   Longest inter-feature gap: 4
# Read b9429988-f95f-4ca4-a9ba-69b9fbf78f84:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 927, 'end': 1126, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 728, 'end': 927, 'length': 199, 'strand': 1}], '3UTR': [{'start': 628, 'end': 728, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 394, 'end': 628, 'length': 234, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 395, 'length': 198, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 334
#   Longest inter-feature gap: 0
# Read 62dd2b0c-5f0e-42c2-80fd-15ea6b6766f7:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 205, 'length': 205, 'strand': 1}], '5end_200nt': [{'start': 205, 'end': 406, 'length': 201, 'strand': 1}], 'Transgene': [{'start': 406, 'end': 1811, 'length': 1405, 'strand': 1}], '3UTR': [{'start': 1811, 'end': 1911, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1911, 'end': 2110, 'length': 199, 'strand': 1}], '3end_400nt': [{'start': 2110, 'end': 2308, 'length': 198, 'strand': 1}]})
#   Insertion length: 1505
#   Longest inter-feature gap: 0
# Read 0126b8fa-135e-40ea-b1f8-223eb1ef678d:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1404, 'end': 1571, 'length': 167, 'strand': 1}], '3UTR': [{'start': 1105, 'end': 1205, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 404, 'end': 1105, 'length': 701, 'strand': 1}], '5end_200nt': [{'start': 206, 'end': 400, 'length': 194, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 206, 'length': 206, 'strand': 1}]})
#   Insertion length: 801
#   Longest inter-feature gap: 199
# Read 7a4775f9-9c2b-4f8d-a02f-438e5de7b172:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 201, 'length': 201, 'strand': 1}], '5end_200nt': [{'start': 215, 'end': 397, 'length': 182, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1103, 'length': 706, 'strand': 1}], '3UTR': [{'start': 1103, 'end': 1199, 'length': 96, 'strand': 1}], '3end_200nt': [{'start': 1199, 'end': 1400, 'length': 201, 'strand': 1}], '3end_400nt': [{'start': 1399, 'end': 1602, 'length': 203, 'strand': 1}]})
#   Insertion length: 802
#   Longest inter-feature gap: 14
# Read a2e98697-01c2-4c48-9fca-fbfd990b5c13:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2673, 'end': 2873, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 2473, 'end': 2673, 'length': 200, 'strand': 1}], '3UTR': [{'start': 2373, 'end': 2473, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 1189, 'end': 2373, 'length': 1184, 'strand': 1}, {'start': 396, 'end': 661, 'length': 265, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 396, 'length': 199, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1284
#   Longest inter-feature gap: 528
# Read cf6a0860-a09a-48c7-a587-4034bc0f9e40:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2107, 'end': 2307, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1907, 'end': 2107, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1807, 'end': 1907, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 406, 'end': 1807, 'length': 1401, 'strand': 1}], '5end_200nt': [{'start': 206, 'end': 406, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 206, 'length': 206, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 0
# Read a022002c-815a-4a37-b316-f75bbcb2eff2:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 397, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1799, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1896, 'length': 97, 'strand': 1}], '3end_200nt': [{'start': 1896, 'end': 2096, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2096, 'end': 2295, 'length': 199, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 0
# Read 917e6dec-6687-4f9b-b609-8c11c2b40402:
# ...
# Read 2a727143-8b49-47a9-97c9-1edae424693e:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 397, 'length': 201, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1799, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1899, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1899, 'end': 2099, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2099, 'end': 2299, 'length': 200, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read ce8e2f8a-e9b1-4236-8b30-4c8493bb2d05:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 198, 'length': 198, 'strand': 1}], '5end_200nt': [{'start': 198, 'end': 395, 'length': 197, 'strand': 1}], 'Transgene': [{'start': 395, 'end': 1780, 'length': 1385, 'strand': 1}], '3UTR': [{'start': 1781, 'end': 1880, 'length': 99, 'strand': 1}], '3end_200nt': [{'start': 1880, 'end': 2079, 'length': 199, 'strand': 1}]})
#   Insertion length: 1485
#   Longest inter-feature gap: 1
# Read 002460c8-9f2d-4ff4-98d5-640165165e7c:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2089, 'end': 2289, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1889, 'end': 2089, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1789, 'end': 1889, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 393, 'end': 1789, 'length': 1396, 'strand': 1}], '5end_200nt': [{'start': 195, 'end': 393, 'length': 198, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 195, 'length': 195, 'strand': 1}]})
#   Insertion length: 1496
#   Longest inter-feature gap: 0
# Read fb6467c3-931f-4011-9377-99d316da89d0:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2099, 'end': 2302, 'length': 203, 'strand': 1}], '3end_200nt': [{'start': 1897, 'end': 2099, 'length': 202, 'strand': 1}], '3UTR': [{'start': 1796, 'end': 1897, 'length': 101, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1796, 'length': 1399, 'strand': 1}], '5end_200nt': [{'start': 200, 'end': 397, 'length': 197, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 198, 'length': 198, 'strand': 1}]})
#   Insertion length: 1500
#   Longest inter-feature gap: 2
# Read 94f447b1-2d42-42b4-8807-a970be1ea067:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 194, 'length': 194, 'strand': 1}], '5end_200nt': [{'start': 194, 'end': 394, 'length': 200, 'strand': 1}], 'Transgene': [{'start': 394, 'end': 1797, 'length': 1403, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1897, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1897, 'end': 2097, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2097, 'end': 2297, 'length': 200, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read 6fe3429f-caf4-4e0a-8822-2b90beec3eae:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2096, 'end': 2297, 'length': 201, 'strand': 1}], '3end_200nt': [{'start': 1896, 'end': 2096, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1796, 'end': 1896, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1796, 'length': 1399, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 397, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 0
# Read cfe1ef5f-0acb-4c97-a8d6-b6b7e4da3dac:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2096, 'end': 2295, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1896, 'end': 2096, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1896, 'length': 99, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1797, 'length': 1400, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 397, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 0
# Read 03b61255-3b57-4ade-b12f-b3ba30f8c767:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2098, 'end': 2298, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1900, 'end': 2098, 'length': 198, 'strand': 1}], '3UTR': [{'start': 1800, 'end': 1900, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 397, 'end': 1800, 'length': 1403, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 397, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read 82ef217a-e8aa-4110-a0a3-d977a8e503fb:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2043, 'end': 2241, 'length': 198, 'strand': 1}], '3end_200nt': [{'start': 1843, 'end': 2043, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1743, 'end': 1843, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 339, 'end': 1743, 'length': 1404, 'strand': 1}], '5end_200nt': [{'start': 141, 'end': 339, 'length': 198, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 141, 'length': 141, 'strand': 1}]})
#   Insertion length: 1504
#   Longest inter-feature gap: 0
# Read 71ea2cbd-566e-4e2e-88bc-ca829c5f7160:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2102, 'end': 2301, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1900, 'end': 2102, 'length': 202, 'strand': 1}], '3UTR': [{'start': 1798, 'end': 1900, 'length': 102, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1798, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 396, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 1504
#   Longest inter-feature gap: 0
# Read 2d9300c0-c945-443f-8e05-1d2399159195:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2095, 'end': 2295, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1895, 'end': 2095, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1795, 'end': 1895, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1795, 'length': 1399, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 396, 'length': 199, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 0
# Read 1160cfe1-f953-4e9b-b9a9-ecaabd1b181e:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 203, 'length': 203, 'strand': 1}], '5end_200nt': [{'start': 203, 'end': 401, 'length': 198, 'strand': 1}], 'Transgene': [{'start': 401, 'end': 1799, 'length': 1398, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1900, 'length': 101, 'strand': 1}], '3end_200nt': [{'start': 1900, 'end': 2100, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2099, 'end': 2298, 'length': 199, 'strand': 1}]})
#   Insertion length: 1499
#   Longest inter-feature gap: 0
# Read 6e2f499c-c1a2-4118-b661-2df67ca2d2bf:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2096, 'end': 2297, 'length': 201, 'strand': 1}], '3end_200nt': [{'start': 1903, 'end': 2097, 'length': 194, 'strand': 1}], '3UTR': [{'start': 1798, 'end': 1894, 'length': 96, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1798, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 396, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 1498
#   Longest inter-feature gap: 9
# Read 769932f4-b97d-4825-a68d-7523febe75d8:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2099, 'end': 2299, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 1896, 'end': 2099, 'length': 203, 'strand': 1}], '3UTR': [{'start': 1796, 'end': 1896, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1796, 'length': 1400, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 396, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 1500
#   Longest inter-feature gap: 0
# Read 39bb715f-0b17-4218-b23d-d42df17d2f6a:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 186, 'length': 186, 'strand': 1}], '5end_200nt': [{'start': 186, 'end': 383, 'length': 197, 'strand': 1}], 'Transgene': [{'start': 385, 'end': 1767, 'length': 1382, 'strand': 1}], '3UTR': [{'start': 1771, 'end': 1871, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1871, 'end': 2050, 'length': 179, 'strand': 1}], '3end_400nt': [{'start': 2066, 'end': 2255, 'length': 189, 'strand': 1}]})
#   Insertion length: 1486
#   Longest inter-feature gap: 16
# Read 97759eda-e226-4791-96c1-4b6deb0ba937:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 607, 'end': 803, 'length': 196, 'strand': 1}], '3end_200nt': [{'start': 407, 'end': 607, 'length': 200, 'strand': 1}], '5end_200nt': [{'start': 206, 'end': 407, 'length': 201, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 206, 'length': 206, 'strand': 1}]})
#   Insertion length: 0
#   Longest inter-feature gap: 0
# Read c0651c56-ec45-4984-8d81-b8fb9305fffd:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 190, 'length': 190, 'strand': 1}], '5end_200nt': [{'start': 190, 'end': 390, 'length': 200, 'strand': 1}], '3end_200nt': [{'start': 390, 'end': 589, 'length': 199, 'strand': 1}], '3end_400nt': [{'start': 593, 'end': 775, 'length': 182, 'strand': 1}]})
#   Insertion length: 0
#   Longest inter-feature gap: 4
# Read f49598cd-95a5-4555-b333-0938df4b4d5f:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 192, 'length': 192, 'strand': 1}], '5end_200nt': [{'start': 192, 'end': 391, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 391, 'end': 1793, 'length': 1402, 'strand': 1}], '3UTR': [{'start': 1793, 'end': 1894, 'length': 101, 'strand': 1}], '3end_200nt': [{'start': 1894, 'end': 2094, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 2093, 'end': 2292, 'length': 199, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 0
# Read d974889f-d6e6-42d8-bec5-10d6f3c4cd23:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 203, 'length': 203, 'strand': 1}], '5end_200nt': [{'start': 203, 'end': 404, 'length': 201, 'strand': 1}], 'Transgene': [{'start': 404, 'end': 1800, 'length': 1396, 'strand': 1}], '3UTR': [{'start': 1800, 'end': 1900, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 1900, 'end': 2106, 'length': 206, 'strand': 1}], '3end_400nt': [{'start': 2104, 'end': 2303, 'length': 199, 'strand': 1}]})
#   Insertion length: 1496
#   Longest inter-feature gap: 0
# Read 4efbc538-9211-41f1-a3f0-c1ccba81c9da:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2096, 'end': 2295, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1897, 'end': 2097, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1797, 'end': 1897, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 394, 'end': 1797, 'length': 1403, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 390, 'length': 193, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1503
#   Longest inter-feature gap: 4
# Read 8c3102f7-f731-42e1-af8b-1445193f62d2:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2097, 'end': 2300, 'length': 203, 'strand': 1}], '3end_200nt': [{'start': 1898, 'end': 2097, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1898, 'length': 99, 'strand': 1}], 'Transgene': [{'start': 398, 'end': 1799, 'length': 1401, 'strand': 1}], '5end_200nt': [{'start': 197, 'end': 398, 'length': 201, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 197, 'length': 197, 'strand': 1}]})
#   Insertion length: 1500
#   Longest inter-feature gap: 0
# Read 1afab484-3dae-4132-9ded-4a0fb3da0172:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 395, 'length': 199, 'strand': 1}], 'Transgene': [{'start': 395, 'end': 529, 'length': 134, 'strand': 1}, {'start': 521, 'end': 949, 'length': 428, 'strand': 1}, {'start': 993, 'end': 1127, 'length': 134, 'strand': 1}], '3UTR': [{'start': 1127, 'end': 1228, 'length': 101, 'strand': 1}], '3end_200nt': [{'start': 1257, 'end': 1439, 'length': 182, 'strand': 1}], '3end_400nt': [{'start': 1436, 'end': 1638, 'length': 202, 'strand': 1}]})
#   Insertion length: 554
#   Longest inter-feature gap: 44
# Read 713d6040-23a6-4f25-bc08-cc2712306d65:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 938, 'end': 1140, 'length': 202, 'strand': 1}], '3end_200nt': [{'start': 738, 'end': 938, 'length': 200, 'strand': 1}], '3UTR': [{'start': 638, 'end': 738, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 400, 'end': 638, 'length': 238, 'strand': 1}], '5end_200nt': [{'start': 198, 'end': 395, 'length': 197, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 198, 'length': 198, 'strand': 1}]})
#   Insertion length: 338
#   Longest inter-feature gap: 5
# Read 69c2be44-a361-4248-a3b5-24bc2fd9d15e:
#   Feature lengths: defaultdict(<class 'list'>, {'5end_400nt': [{'start': 0, 'end': 191, 'length': 191, 'strand': 1}], '5end_200nt': [{'start': 191, 'end': 389, 'length': 198, 'strand': 1}], 'Transgene': [{'start': 394, 'end': 632, 'length': 238, 'strand': 1}], '3UTR': [{'start': 632, 'end': 732, 'length': 100, 'strand': 1}], '3end_200nt': [{'start': 732, 'end': 932, 'length': 200, 'strand': 1}], '3end_400nt': [{'start': 932, 'end': 1132, 'length': 200, 'strand': 1}]})
#   Insertion length: 338
#   Longest inter-feature gap: 5
# Read cf14f80b-e5c8-4412-8f19-6729cc60d7af:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2098, 'end': 2297, 'length': 199, 'strand': 1}], '3end_200nt': [{'start': 1898, 'end': 2098, 'length': 200, 'strand': 1}], '3UTR': [{'start': 1798, 'end': 1898, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 396, 'end': 1798, 'length': 1402, 'strand': 1}], '5end_200nt': [{'start': 196, 'end': 396, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 196, 'length': 196, 'strand': 1}]})
#   Insertion length: 1502
#   Longest inter-feature gap: 0
# Read 0eb4a135-1e37-482e-9b71-b090a7e17f9a:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2098, 'end': 2299, 'length': 201, 'strand': 1}], '3end_200nt': [{'start': 1899, 'end': 2098, 'length': 199, 'strand': 1}], '3UTR': [{'start': 1799, 'end': 1899, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 398, 'end': 1799, 'length': 1401, 'strand': 1}], '5end_200nt': [{'start': 198, 'end': 398, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 198, 'length': 198, 'strand': 1}]})
#   Insertion length: 1501
#   Longest inter-feature gap: 0
# Read b0d7cc7d-e495-47a9-a981-35ed96748eb0:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 1091, 'end': 1287, 'length': 196, 'strand': 1}], '3end_200nt': [{'start': 888, 'end': 1088, 'length': 200, 'strand': 1}], '3UTR': [{'start': 788, 'end': 888, 'length': 100, 'strand': 1}], 'Transgene': [{'start': 499, 'end': 788, 'length': 289, 'strand': 1}, {'start': 406, 'end': 501, 'length': 95, 'strand': 1}], '5end_200nt': [{'start': 206, 'end': 406, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 206, 'length': 206, 'strand': 1}]})
#   Insertion length: 482
#   Longest inter-feature gap: 3
# Read d09e3772-6650-4893-bebb-be504321b865:
#   Feature lengths: defaultdict(<class 'list'>, {'3end_400nt': [{'start': 2109, 'end': 2303, 'length': 194, 'strand': 1}], '3end_200nt': [{'start': 1912, 'end': 2109, 'length': 197, 'strand': 1}], '3UTR': [{'start': 1819, 'end': 1912, 'length': 93, 'strand': 1}], 'Transgene': [{'start': 403, 'end': 1816, 'length': 1413, 'strand': 1}], '5end_200nt': [{'start': 203, 'end': 403, 'length': 200, 'strand': 1}], '5end_400nt': [{'start': 0, 'end': 203, 'length': 203, 'strand': 1}]})
#   Insertion length: 1509
#   Longest inter-feature gap: 3

# %% [markdown]
# ## Helper Function

# %% [markdown]
# ## 4. Classification Logic

# %%
##################################################
# 3. CLASSIFICATION LOGIC
##################################################

def classify_read(
    read_id,
    feature_dict,
    max_insertion_len,
    max_inter_gap,
    ref_lengths,
    random_integration_threshold=50,
    indels=10,
    min_gap_distance=20,
):
    """
    Return an integer or string that indicates the category of the read based on logic:
      1) Complete Integration
      2) FivePrimeTruncations 
      4) Snapback
      5) Jumps within the Insert
      6) Duplication ROI
      7) Random insertion
      8) Other
    """

    
    # === Helper variables ===
    # convenience
    ref_insertion_len = ref_lengths["Insert"]
    # e.g. 3end_200nt length from reference
    ref_5end_200_len = ref_lengths["5end_200nt"]

    # Check # of times each feature is apparent
    # We define “duplicated” if any feature type count is >=2
    any_feature_duplicated = any(len(v) >= 2 for v in feature_dict.values())


    # Grab 5end_200nt length in this read from feature_dict. The key is "5end_200nt"
    length_5end_200nt_gb = 0
    if "5end_200nt" in feature_dict:
        # Get the longest 5end_200nt segment length
        length_5end_200nt_gb = max(
            seg["length"] for seg in feature_dict["5end_200nt"]
        )
    

    # # [TYPE] 7. Random insertion non-annotated
    if (max_inter_gap >= random_integration_threshold 
        and not any_feature_duplicated):
        return 7, "RANDOM_INSERT"

    
    # [TYPE] 2. FivePrimeTruncations Transgene integration
    # 5end_200nt >= ref_3end_200_len - indels
    #if (max_insertion_len < ref_insertion_len - indels
    if not any_feature_duplicated:
        return 2, "FivePrimeTruncations"

    # [TYPE] 1. Complete Integration
    # insertion_length ~ ref_transgene_length + ref_UTR_length ± Indels
    # also require 3end_200nt >= ref_3end_200_len - indels 
    # if (ref_insertion_len - indels <= max_insertion_len <= ref_insertion_len + indels
    #     and not any_feature_duplicated):
    #     return 1, "COMPLETE"
    
    
    # [TYPE] 4. Snapback
    # "Number of at least 1 featuretype > 1 and in varying orientations"

    for ftype, flist in feature_dict.items():
        # Only consider duplicated features
        if len(flist) <= 1:
            continue

        # Check if there's a mix of strands
        if any(f["strand"] == 1 for f in flist) and any(f["strand"] == -1 for f in flist):
            return 4, "SNAPBACK"

    # [TYPE] 5. Jumps within insert
    # "seperately check whether there are Featuretype Transgene or UTR > 1, gap in between them"
    #   if transgene_count > 1 or UTR_count > 1 and ... => #5
    # no other feature should be in between the duplicated features

    for ftype, flist in feature_dict.items():
        # -- Filter out non-cases
        # Only consider duplicated features and Transgene/UTR
        if (len(flist) <= 1) or (ftype not in {"Transgene", "3UTR"}):
            continue
        # Only consider features that are close to each other
        flist_copy = flist.copy()
        flist_copy.sort(key=lambda x: x["start"])


        # Ensure that the features are close together (within random_integration_threshold) (alternatively check whether different feature in between)
        duplicate_in_proximity = True
        for i in range(1, len(flist_copy)):
            if flist_copy[i]["start"] - flist_copy[i-1]["end"] >= random_integration_threshold:
                duplicate_in_proximity = False
                break

        # -- Calculate whether there's a gap between the features
    
        # get a list of reference coordinates of the feature type 
        ftype_ref_positions = read_ref_positions[(read_id, ftype)]
        ftype_ref_positions.sort(key=lambda x: x[0])
        # check list for overlapping element
        has_no_overlap = True
        for i in range(1, len(ftype_ref_positions)):
            if ftype_ref_positions[i][0] < ftype_ref_positions[i-1][1]:
                has_no_overlap = False
                break

        if has_no_overlap and duplicate_in_proximity:
            return 5, "Jumps"


    # 6. Duplication ROI
    # "Number of at least 1 featuretype >1 and in same orientation"
    # Or insertion length > ref_insertion_len + indels
    if any_feature_duplicated: # and not has_no_overlap: # TODO CHECK if we can add has_no_overlap
        return 6, "DUPLICATION_ROI"

    # 8. Other
    # If none of the above matched, but no random_integration_detected
    return 8, "OTHER"


gb_file = "00-Data/feature_annotated/Repeatmasker_transgene_filtered.gb"
for read_record in SeqIO.parse(gb_file, "genbank"):
    if read_record.id != "e6a618ab-0e63-4525-b142-63ee327895e0_trimmed":
        continue
    print(read_record.id)
    feature_dict, max_insertion_len, max_inter_gap = get_feature_info(read_record)
    print(classify_read(read_record.id, feature_dict, max_insertion_len, max_inter_gap, ref_lengths))
    break

# %% [markdown]
# ## Main Pipeline

# %%
import matplotlib.pyplot as plt
from Bio import SeqIO
from collections import defaultdict

def main(ref_fasta, gb_file, out_gb="reads_categorized.gb", indels=20):
    # 0) Counters variables
    transgene_counter_category = defaultdict(lambda: defaultdict(int))

    # 1) Get reference feature lengths
    ref_lengths = parse_reference_fasta(ref_fasta)

    ref_insertion_len = ref_lengths["Insert"]
    ref_Transgene_len = ref_lengths["Transgene"]

    # 2) Prepare category structure & counters
    categorized_dict = defaultdict(list)  # category_num -> list of SeqRecords
    category_names = {
        1: "COMPLETE",
        2: "FivePrimeTruncations",
        3: "28S_DEL_5END",
        4: "SNAPBACK",
        5: "Jumps",
        6: "DUPLICATION_ROI",
        7: "RANDOM_INSERT",
        8: "OTHER",
    }

    # 3) SINGLE PASS: Classify each read, skip discarded, count only if not discarded
    for read_record in SeqIO.parse(gb_file, "genbank"):
        # a) Get feature info (same as your code)
        feature_dict, max_insertion_len, max_inter_gap = get_feature_info(read_record)

        # b) Classify read
        category_num, category_str = classify_read(
            read_record.id,
            feature_dict,
            max_insertion_len,
            max_inter_gap,
            ref_lengths,
            indels=indels
        )

        # c) Check if discarded
        if category_num == -1:
            discarded_counter += 1
            continue  # do not count anything for this read


        # d) transgene counting
        max_Transgene_len = 0
        if "Transgene" in feature_dict:
            max_Transgene_len = max(seg["length"] for seg in feature_dict["Transgene"])

        if (ref_Transgene_len - indels <= max_Transgene_len <= ref_Transgene_len + indels):
            transgene_counter_category[category_str]["within"] += 1
        elif max_Transgene_len < (ref_Transgene_len - indels):
            transgene_counter_category[category_str]["less"] += 1

        # e) Label read ID and store in category
        read_record.id = f"{category_names[category_num]}-{read_record.id}"
        read_record.name = read_record.id
        read_record.description = f"Category {category_num}: {category_str}"

        categorized_dict[category_num].append(read_record)

    # 4) Build final list of reads, sorted by category
    all_categorized_reads = []
    for cnum in sorted(categorized_dict.keys()):
        all_categorized_reads.extend(categorized_dict[cnum])

    # 5) Write out the final GenBank
    SeqIO.write(all_categorized_reads, out_gb, "genbank")

    # 6) Make a bar chart
    #    The categories go from 1..8. We'll use 0 for "discarded" if you want to show it
    category_counts = []
    for cnum in range(1, 9):
        cat_count = len(categorized_dict.get(cnum, []))
        category_counts.append((cnum, cat_count))

    labels = [f"{cnum}:{category_names[cnum]}" for cnum, _ in category_counts]
    counts = [count for _, count in category_counts]

    plt.figure(figsize=(10,6))
    bars = plt.bar(labels, counts)
    plt.xticks(rotation=45, ha="right")
    plt.ylabel("Number of Reads")
    plt.title("Reads per Category")
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height, str(height),
                 ha='center', va='bottom', fontsize=9)
    plt.tight_layout()
    plt.savefig("00-Data/read_category.png", dpi=150)
    plt.close()

    # 7) Print summary
    print(f"Wrote categorized GenBank to: {out_gb}")
    print("Category counts:")
    for cnum, cnt in category_counts:
        print(f"  {cnum} ({category_names[cnum]}): {cnt}")

    print(f"\n=== Transgene Counting Results ===")
    print(f"Total reads where max_Transgene_len is within ±{indels}: {sum(x['within'] for x in transgene_counter_category.values())}")
    print(f"Total reads where max_Transgene_len < (ref_Transgene_len - {indels}): {sum(x['less'] for x in transgene_counter_category.values())}")
    print()
    for category, counts in transgene_counter_category.items():
        print(f"Category {category}:")
        print(f"  Number of reads where max_Transgene_len is within ±{indels}: {counts['within']}")
        print(f"  Number of reads where max_Transgene_len < (ref_Transgene_len - {indels}): {counts['less']}")
        print()
   
    
    return categorized_dict 

if __name__ == "__main__":
    ref_fasta = "00-Data/references/ref_28s_features.fasta"
    gb_file   = "00-Data/feature_annotated/Repeatmasker_transgene_filtered.gb"
    out_gb    = "00-Data/feature_annotated/Repeatmasker_transgene_classified.gb"

    indels= 10

    categorized_dict = main(ref_fasta, gb_file, out_gb, indels=indels)
# Out:
# Wrote categorized GenBank to: 00-Data/feature_annotated/Repeatmasker_transgene_classified.gb
# Category counts:
#   1 (COMPLETE): 0
#   2 (FivePrimeTruncations): 755
#   3 (28S_DEL_5END): 0
#   4 (SNAPBACK): 3
#   5 (Jumps): 60
#   6 (DUPLICATION_ROI): 25
#   7 (RANDOM_INSERT): 3
#   8 (OTHER): 0
#
# === Transgene Counting Results ===
# Total reads where max_Transgene_len is within ±10: 488
# Total reads where max_Transgene_len < (ref_Transgene_len - 10): 353
#
# Category FivePrimeTruncations:
#   Number of reads where max_Transgene_len is within ±10: 482
#   Number of reads where max_Transgene_len < (ref_Transgene_len - 10): 268
#
# Category Jumps:
#   Number of reads where max_Transgene_len is within ±10: 0
#   Number of reads where max_Transgene_len < (ref_Transgene_len - 10): 60
#
# Category DUPLICATION_ROI:
#   Number of reads where max_Transgene_len is within ±10: 4
#   Number of reads where max_Transgene_len < (ref_Transgene_len - 10): 21
#
# Category RANDOM_INSERT:
#   Number of reads where max_Transgene_len is within ±10: 0
#   Number of reads where max_Transgene_len < (ref_Transgene_len - 10): 3
#
# Category SNAPBACK:
#   Number of reads where max_Transgene_len is within ±10: 2
#   Number of reads where max_Transgene_len < (ref_Transgene_len - 10): 1
# /Users/cschaefe/.local/share/miniforge3/envs/RepeatMaster2/lib/python3.10/site-packages/Bio/SeqIO/InsdcIO.py:727: BiopythonWarning: Increasing length of locus line to allow long name. This will result in fields that are not in usual positions.
#   warnings.warn(

# %% [markdown]
# ## Merch Flanking region

# %%
def combine_qualifiers(feature_list):
    # Merge all qualifiers from a list of features into a single dict.
    new_quals = {}
    for ft in feature_list:
        for k, vals in ft.qualifiers.items():
            if k not in new_quals:
                new_quals[k] = list(vals)
            else:
                new_quals[k].extend(vals)
    return new_quals

def merge_all_adjacent_features(feature_list, feature_types, new_feature_type):
    # Merge overlapping or adjacent features of 'feature_type' in a list of features.
    # (Sort by start, combine any that overlap or directly touch (start <= current_end + 1),
    # use earliest start / latest end, merge qualifiers)
    merged = []
    if not feature_list:
        return merged  # no features of this type
    
    # Sort by start location
    feature_list.sort(key=lambda f: f.location.start.position)

    current_feat = feature_list[0]
    overlapping_feats = [current_feat]

    for f in feature_list[1:]:
        start_cur = current_feat.location.start.position
        end_cur = current_feat.location.end.position
        start_f = f.location.start.position
        end_f = f.location.end.position

        # Check if the feature types are in the right order to merged
        has_right_order = current_feat.type == feature_types[0] and f.type == feature_types[1]

        # Check if the features are overlapping or adjacent
        is_adjacent_on_ref = (
            int(current_feat.qualifiers["ref_position_end"][0]) == ref_lengths[current_feat.type]
            and
            int(f.qualifiers["ref_position_start"][0]) == 0
        )
        
        # if not is_adjacent_on_ref:
        #     print(current_feat.qualifiers["ref_position_end"][0], f.qualifiers["ref_position_start"][0])

        # If f overlaps or touches current_feat AND the feature types match the condition
        if has_right_order and is_adjacent_on_ref and start_f <= end_cur + 1:
            new_start = min(start_cur, start_f)
            new_end = max(end_cur, end_f)
            strand = current_feat.location.strand
            # Update the current feature's location
            current_feat.location = FeatureLocation(new_start, new_end, strand=strand)
            # Keep track for qualifiers merging
            overlapping_feats.append(f)
        else:
            # Finalize the current_feat with merged qualifiers
            current_feat.qualifiers = combine_qualifiers(overlapping_feats)
            current_feat.type = new_feature_type
            merged.append(current_feat)

            # Start a new merge group
            current_feat = f
            overlapping_feats = [f]

    # Final flush: merge the last group
    current_feat.qualifiers = combine_qualifiers(overlapping_feats)
    current_feat.type = new_feature_type
    merged.append(current_feat)

    return merged

def merge_ends_in_record(record):
    """
    1. Rename feature types (3end_200nt/3end_400nt -> 3end, 5end_200nt/5end_400nt -> 5end).
    2. Merge adjacent/overlapping 3end features into one, and 5end features into one.
    Returns the updated record.
    """
    # Separate features into 3end, 5end, and others
    feats_3end = []
    feats_5end = []
    other_feats = []

    # Feature types to merge, the order is important. 
    # Only ones from feature_types_Xend[0] -> feature_types_Xend[1] will be merged.
    feature_types_3end = ("3end_200nt", "3end_400nt")
    feature_types_5end = ("5end_400nt", "5end_200nt")

    for feat in record.features:
        if feat.type in feature_types_3end:
            feats_3end.append(feat)
        elif feat.type in feature_types_5end:
            feats_5end.append(feat)
        else:
            other_feats.append(feat)

    # Merge each category
    merged_3end = merge_all_adjacent_features(feats_3end, feature_types_3end, new_feature_type="3end")
    merged_5end = merge_all_adjacent_features(feats_5end, feature_types_5end, new_feature_type="5end")

    # Recombine with the unchanged features
    record.features = merged_5end + other_feats + merged_3end
    return record

def rename_and_merge_ends(input_gb, output_gb):
    """
    Reads records from 'input_gb', renames/merges end features in each,
    and writes the updated records to 'output_gb' without overwriting the input.
    """
    # Parse all records
    records = list(SeqIO.parse(input_gb, "genbank"))
    updated_records = []

    # Process each record
    for rec in records:
        updated_rec = merge_ends_in_record(rec)
        updated_records.append(updated_rec)

    # Write out to a new file
    SeqIO.write(updated_records, output_gb, "genbank")

if __name__ == "__main__":
    in_file = "00-Data/feature_annotated/Repeatmasker_transgene_classified.gb"
    out_file = "00-Data/feature_annotated/Repeatmasker_transgene_classified_merged.gb"

    rename_and_merge_ends(in_file, out_file)
    print(f"Updated GenBank file written to: {out_file}")
# Out:
# Updated GenBank file written to: 00-Data/feature_annotated/Repeatmasker_transgene_classified_merged.gb
# /Users/cschaefe/.local/share/miniforge3/envs/RepeatMaster2/lib/python3.10/site-packages/Bio/SeqFeature.py:1940: BiopythonDeprecationWarning: Alias location.position is deprecated and will be removed in a future release. Use location directly, or int(location). However, that will fail for UnknownPosition, and for OneOfPosition and WithinPosition will give the default rather than left-most value.
#   warnings.warn(

# %% [markdown]
# ## Count reads that would have been positive in a ddPCR

# %%
# ------------------------------------------------------------------
# 1. Imports and Setup
# ------------------------------------------------------------------

from Bio import SeqIO

# Define ddPCR primers and probe
FORWARD_PRIMER = "CAGTGCTCTGAATGTCAAAGTG".upper()     # Example: oGE980
REVERSE_PRIMER = "ACTAGTCAATAATCAATGTCAACGG".upper()  # Example: oGE981
PROBE_SEQ = "ACGGCGGGAGTAACTATGACTCTCT".upper()      # Example: oGE982

# Parameters
MISMATCH_THRESHOLDS = [0, 2]        # 0 for exact matches, n for up to n mismatches
DISTANCE_THRESHOLDS = [200, 500]    # Maximum distance between primers in bases

# Path to the FASTQ file (update this path as needed)
FASTQ_FILE = "00-Data/samples_filtered/sample-cutadapt_sup-filtered-trimmed.fastq"

# ------------------------------------------------------------------
# 2. Helper Functions
# ------------------------------------------------------------------

def reverse_complement(seq):
    """Return the reverse complement of a DNA sequence."""
    complement_map = str.maketrans("ACGTN", "TGCAN")
    return seq.translate(complement_map)[::-1]

def hamming_distance(s1, s2):
    """
    Calculate the Hamming distance between two strings.
    Returns the number of mismatches. Assumes len(s1) == len(s2).
    """
    return sum(c1 != c2 for c1, c2 in zip(s1, s2))

def find_approximate_matches(target, query, max_mismatches):
    """
    Find all start positions in 'target' where 'query' matches with ≤max_mismatches.
    Returns a list of start indices.
    """
    matches = []
    t_len = len(target)
    q_len = len(query)
    for start in range(t_len - q_len + 1):
        window = target[start:start + q_len]
        mismatches = hamming_distance(window, query)
        if mismatches is not None and mismatches <= max_mismatches:
            matches.append(start)
    return matches

# Precompute reverse complements
REVERSE_PRIMER_RC = reverse_complement(REVERSE_PRIMER)
FORWARD_PRIMER_RC = reverse_complement(FORWARD_PRIMER)
PROBE_RC = reverse_complement(PROBE_SEQ)

# ------------------------------------------------------------------
# 3. Main Logic
# ------------------------------------------------------------------

# Initialize counters for each condition
# Structure: positive_reads[(max_mismatches, max_distance)] = set of read_ids
positive_reads = { (mm, dist): set() for mm in MISMATCH_THRESHOLDS for dist in DISTANCE_THRESHOLDS }

# Process each read in the FASTQ file
for record in SeqIO.parse(FASTQ_FILE, "fastq"):
    read_id = record.id
    seq = str(record.seq).upper()

    # Consider both forward and reverse strands
    strands = {
        'forward': seq,
        'reverse': reverse_complement(seq)
    }

    for strand, sequence in strands.items():
        for mm in MISMATCH_THRESHOLDS:
            # Find all forward primer matches
            fwd_matches = find_approximate_matches(sequence, FORWARD_PRIMER, mm)
            
            # Find all reverse primer matches
            rev_matches = find_approximate_matches(sequence, REVERSE_PRIMER_RC, mm)
            
            # Iterate through all possible primer pairs
            for fwd_start in fwd_matches:
                for rev_start in rev_matches:
                    # Ensure forward primer is upstream of reverse primer
                    if fwd_start < rev_start:
                        # Calculate distance between primers
                        fwd_end = fwd_start + len(FORWARD_PRIMER)
                        distance = rev_start - fwd_end
                        
                        for dist_threshold in DISTANCE_THRESHOLDS:
                            if distance <= dist_threshold:
                                # Define the region between primers
                                between_region = sequence[fwd_end:rev_start]
                                
                                # Check for probe presence in the between_region
                                probe_forward = find_approximate_matches(between_region, PROBE_SEQ, mm)
                                probe_reverse = find_approximate_matches(between_region, PROBE_RC, mm)
                                
                                if probe_forward or probe_reverse:
                                    positive_reads[(mm, dist_threshold)].add(read_id)
                    
                    # Additionally, check for reverse orientation
                    # Forward primer reverse complement and reverse primer forward
                    # This accounts for reads aligned to the reverse strand
                    # Note: Since we're already considering both strands, this may be redundant
                    # depending on the dataset. Including for completeness.
                    elif rev_start < fwd_start:
                        # Calculate distance between primers
                        rev_end = rev_start + len(REVERSE_PRIMER_RC)
                        distance = fwd_start - rev_end
                        
                        for dist_threshold in DISTANCE_THRESHOLDS:
                            if distance <= dist_threshold:
                                # Define the region between primers
                                between_region = sequence[rev_end:fwd_start]
                                
                                # Check for probe presence in the between_region
                                probe_forward = find_approximate_matches(between_region, PROBE_SEQ, mm)
                                probe_reverse = find_approximate_matches(between_region, PROBE_RC, mm)
                                
                                if probe_forward or probe_reverse:
                                    positive_reads[(mm, dist_threshold)].add(read_id)

# ------------------------------------------------------------------
# 4. Summary of Results
# ------------------------------------------------------------------

print("Number of Positive Reads in ddPCR Assay under Various Conditions:\n")

for mm in MISMATCH_THRESHOLDS:
    for dist in DISTANCE_THRESHOLDS:
        count = len(positive_reads[(mm, dist)])
        mismatch_desc = f"≤{mm} mismatches" if mm > 0 else "Exact matches (0 mismatches)"
        print(f"- {mismatch_desc} & Distance ≤{dist} bases: {count} reads")

print("\nProcessing Complete.")
# Out:
# Number of Positive Reads in ddPCR Assay under Various Conditions:
#
# - Exact matches (0 mismatches) & Distance ≤200 bases: 470 reads
# - Exact matches (0 mismatches) & Distance ≤500 bases: 470 reads
# - ≤2 mismatches & Distance ≤200 bases: 519 reads
# - ≤2 mismatches & Distance ≤500 bases: 519 reads
#
# Processing Complete.
